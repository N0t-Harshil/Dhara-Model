# %% [markdown]
# # Methos Class Model — Training Interactive Notebook
#
# Use this notebook on JupyterLab (remote GPU server) to launch and monitor MethosV3 training runs.

# %%
# 1. Download Tokenizer if not present
# !python main.py download-tokenizer

# %%
# 2. Run Parameter Audit Script
# !python scripts/param_audit.py

# %%
# 3. Launch 4-GPU FSDP Full Training Sequence (or single GPU)
# To launch 4-GPU torchrun:
# !bash scripts/train_4gpu.sh

# Or single GPU debug run:
# !python main.py full-training --gpu 0

# %%
# 4. Test Text Generation from Checkpoint
# !python main.py generate --prompt "def fibonacci(n):"
